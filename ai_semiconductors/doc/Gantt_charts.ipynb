# %%
import pandas as pd
import numpy as np
import altair as alt
# %matplotlib inline

# %%
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ## Gantt chart 04-13-2020

# %%
df_200413 = pd.read_excel("./GanttChart_data.xlsx", sheet_name='200413')
df_200413
# Out:
#                               Task      Category Start Date   End Date
# 0  Descriptor/Property correlation  Initial data 2020-04-13 2020-04-22
# 1     ML exploration (NN, RF, KRR)  Initial data 2020-04-15 2020-04-29
# 2           Train models with data  Initial data 2020-04-15 2020-04-29
# 3             Have model completed       Overall 2020-06-05 2020-06-19

# %%
df = df_200413
df["Start Date"] = pd.to_datetime(df["Start Date"], )
df["End Date"] = pd.to_datetime(df["End Date"])

chart = alt.Chart(df, title='Gantt Chart 04-13-2020').mark_bar(size=20).encode(
    x='Start Date',
    x2='End Date',
    y=alt.Y('Task', 
            sort=list(df.sort_values(["End Date", "Start Date"])
                                    ["Task"])), # Custom sorting
    color='Category'
    ).configure_axis(
        labelFontSize=12,
        titleFontSize=16
    ).configure_title(
        fontSize=24
    ).properties(
        width=700,
        height=200
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Gantt chart 04-22-2020

# %%
df_200422 = pd.read_excel("./GanttChart_data.xlsx", sheet_name='200422')
df_200422
# Out:
#                                                            Task      Category  \
# 0                               Descriptor/Property correlation  Initial data
# 1                                 ML exploration (NN, RFR, KRR)  Initial data
# 2                                    Train models with DFT data  Initial data
# 3                           Clean DFT data: outliers, normalize    Total data
# 4                      Descriptor importance: remove unecessary    Total data
# 5          Train models with new DFT data (NN, RFR, LASSO, GPR)    Total data
# 6                             Test models with mixed alloy data    Total data
# 7                                   Brainstorm more descriptors    Lit Review
# 8  Expected improvement:informed selection of new training data         Bonus
# 9                                          Have model completed       Overall
#
#   Start Date   End Date
# 0 2020-04-13 2020-04-22
# 1 2020-04-15 2020-04-22
# 2 2020-04-15 2020-04-22
# ...

# %%
df = df_200422
df["Start Date"] = pd.to_datetime(df["Start Date"], )
df["End Date"] = pd.to_datetime(df["End Date"])

chart = alt.Chart(df, title='Gantt Chart 04-22-2020').mark_bar(size=20).encode(
    x='Start Date',
    x2='End Date',
    y=alt.Y('Task', 
            sort=list(df.sort_values(["End Date", "Start Date"])
                                    ["Task"])), # Custom sorting
    color='Category'
    ).configure_axis(
        labelFontSize=12,
        titleFontSize=16
    ).configure_title(
        fontSize=24
    ).properties(
        width=700,
        height=250
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Gantt chart 05-01-2020

# %%
df_200501 = pd.read_excel("./GanttChart_data.xlsx", sheet_name='200501')
df_200501
# Out:
#                                                              Task  \
# 0                                 Descriptor/Property correlation
# 1                                   ML exploration (NN, RFR, KRR)
# 2                                      Train models with DFT data
# 3                             Clean DFT data: outliers, normalize
# 4                        Descriptor importance: remove unecessary
# 5            Train models with new DFT data (NN, RFR, LASSO, GPR)
# 6                               Test models with mixed alloy data
# 7                               Data Visualization: PCA, KNN, MDS
# 8                       Expanded dataset (12k points) exploration
# 9                                     Brainstorm more descriptors
# 10  Expected improvement: informed selection of new training data
# 11                                           Have model completed
#
#           Category Start Date   End Date
# 0     Initial data 2020-04-13 2020-04-22
# ...

# %%
df = df_200501
df["Start Date"] = pd.to_datetime(df["Start Date"], )
df["End Date"] = pd.to_datetime(df["End Date"])

chart = alt.Chart(df, title='Gantt Chart 05-01-2020').mark_bar(size=20).encode(
    x='Start Date',
    x2='End Date',
    y=alt.Y('Task', 
            sort=list(df.sort_values(["End Date", "Start Date"])
                                    ["Task"])), # Custom sorting
    color='Category'
    ).configure_axis(
        labelFontSize=12,
        titleFontSize=16
    ).configure_title(
        fontSize=24
    ).properties(
        width=700,
        height=300
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Gantt chart 05-15-2020

# %%
df_200515 = pd.read_excel("./GanttChart_data.xlsx", sheet_name='200515')
df_200515
# Out:
#                                                              Task  \
# 0                                 Descriptor/Property correlation
# 1                                   ML exploration (NN, RFR, KRR)
# 2                                      Train models with DFT data
# 3                             Clean DFT data: outliers, normalize
# 4                        Descriptor importance: remove unecessary
# 5            Train models with new DFT data (NN, RFR, LASSO, GPR)
# 6                               Test models with mixed alloy data
# 7                               Data Visualization: PCA, KNN, MDS
# 8                         Outlier detection and removal: PCA, KNN
# 9                       Expanded dataset (12k points) exploration
# 10                                 Outlier detection and removal
# 11                             Uncertainty prediction: all models
# 12                              Model tuning with new descriptors
# ...

# %%
df = df_200515
df["Start Date"] = pd.to_datetime(df["Start Date"], )
df["End Date"] = pd.to_datetime(df["End Date"])

chart = alt.Chart(df, title='Gantt Chart 05-15-2020').mark_bar(size=20).encode(
    x='Start Date',
    x2='End Date',
    y=alt.Y('Task', 
            sort=list(df.sort_values(["End Date", "Start Date"])
                                    ["Task"])), # Custom sorting
    color='Category'
    ).configure_axis(
        labelFontSize=12,
        titleFontSize=16
    ).configure_title(
        fontSize=24
    ).properties(
        width=700,
        height=350
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Gantt chart 06-21-2020

# %%
df_200621 = pd.read_excel("./GanttChart_data.xlsx", sheet_name='200621')
df_200621
# Out:
#                                                       Task        Category  \
# 0                          Descriptor/Property correlation    Initial data
# 1                            ML exploration (NN, RFR, KRR)    Initial data
# 2                               Train models with DFT data    Initial data
# 3                      Clean DFT data: outliers, normalize      Total data
# 4                 Descriptor importance: remove unecessary      Total data
# 5     Train models with new DFT data (NN, RFR, LASSO, GPR)      Total data
# 6                        Test models with mixed alloy data      Total data
# 7                        Data Visualization: PCA, KNN, MDS      Total data
# 8                  Outlier detection and removal: PCA, KNN      Total data
# 9                Expanded dataset (12k points) exploration  Chemical space
# 10                          Outlier detection and removal   Chemical space
# ...

# %%
df = df_200621
df["Start Date"] = pd.to_datetime(df["Start Date"], )
df["End Date"] = pd.to_datetime(df["End Date"])

chart = alt.Chart(df, title='Gantt Chart 06-21-2020').mark_bar(size=20).encode(
    x='Start Date',
    x2='End Date',
    y=alt.Y('Task', 
            sort=list(df.sort_values(["End Date", "Start Date"])
                                    ["Task"])), # Custom sorting
    color='Category'
    ).configure_axis(
        labelFontSize=12,
        titleFontSize=16
    ).configure_title(
        fontSize=24
    ).properties(
        width=700,
        height=400
)

chart
# Out:
# alt.Chart(...)
