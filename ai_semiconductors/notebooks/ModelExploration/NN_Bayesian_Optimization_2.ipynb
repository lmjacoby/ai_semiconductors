# %%
import pandas as pd
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import tensorflow as tf
import statistics as stats
import random as rn
import os
import tensorflow.compat.v1 as tf

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.preprocessing import LabelBinarizer
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import OneHotEncoder 

from keras.models import Sequential
from keras.layers import Dense, Dropout, GaussianNoise
from keras.optimizers import Adam
from keras.regularizers import l1, l2
from keras import initializers as init

from tensorflow.python.keras import backend as K

from math import sqrt
from numpy.random import seed

from skopt import gbrt_minimize, gp_minimize
from skopt.utils import use_named_args
from skopt.space import Real, Categorical, Integer
# Out:
# Using TensorFlow backend.

# %%
# ensure repeatability
K.clear_session()
tf.reset_default_graph()

os.environ['PYTHONHASHSEED'] = '0'
np.random.seed(23)
rn.seed(23)
tf.random.set_random_seed(23)
session_conf = tf.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.Session(graph=tf.get_default_graph(), config=session_conf)
K.set_session(sess)

# %%
data = pd.read_csv("ML_data.csv", sep="|")
data2 = pd.read_csv("add_des.csv", sep="|", index_col=0)
pd.set_option("display.max_columns", None)

# %%
# Parameters
epochs=500
training_size=0.95
batch_size=50
activation='relu'
# learning_rate=1e-3
# adam_decay=1e-2
# dropout_rate=0.15
# noise=1.5e-2
# k_reg= 0.2 # kernal regularizer

# %%
############ DATA PRE-PROCESSING ############ 

# add in various functions to x
x = data.iloc[:, 10:15]
y = data.iloc[:, 6:10]
new_data = x.copy()
with np.errstate(divide='ignore', over='ignore'):
    new_data[x.columns + '^2']=(data[x.columns])**2
    new_data[x.columns + '^3']=(data[x.columns])**3
    new_data[x.columns + 'sqrt']=abs(data[x.columns])**(1/2)
    new_data[x.columns + 'cbrt']=abs(data[x.columns])**(1/3)
    new_data[x.columns + 'e^x']=np.exp(data[x.columns])
    new_data[x.columns + 'e^x-1']=np.expm1(data[x.columns])
    new_data[x.columns + '2^x']=np.exp2(data[x.columns])
    new_data[x.columns + 'lnx']=np.log(abs(data[x.columns]))
    new_data[x.columns + 'log10x']=np.log10(abs(data[x.columns]))
    new_data[x.columns + 'log2x']=np.log2(abs(data[x.columns]))
    new_data[x.columns + 'ln(1+x)']=np.log1p(abs(data[x.columns]))
new_data=new_data.replace([np.inf, -np.inf], np.nan).dropna(axis=1)

# concatenate the newly derived functions from 5 "hot" columns, the rest
# of the descriptors, and the additional descriptors add_des csv (data2)
frames= [new_data, data.iloc[:, 15:52], data2]
func_data=pd.concat(frames, axis=1)

# separate categorical and continuous data 
categorical=pd.DataFrame()
continuous=pd.DataFrame()

for index in func_data.columns:
    if(func_data[index].dtypes == "int"):
        categorical[index]=func_data[index]
    elif(func_data[index].dtypes == "float"):
        continuous[index]=func_data[index]
    else:
        pass

# one hot encode categorical data
onehotencoder = OneHotEncoder()
categorical = onehotencoder.fit_transform(categorical).toarray()

# standardize continuous data
scaler = StandardScaler()
continuous = scaler.fit_transform(continuous)

# re-combine categorical and continuous data
x = np.concatenate((continuous, categorical), axis=1)

# extract y data and standardize (DFT predicted / output)
y = scaler.fit_transform(y)

# input and output dimension
in_dim = x.shape[1]
out_dim = y.shape[1]

# %%
# construct model

def construct_model(k_reg, dropout_rate, learning_rate, noise, adam_decay):
    
    # Create and add layers to model
    model = Sequential()
    #### Input layer
    model.add(Dense(1024,
                    input_dim=in_dim, 
                    activation=activation,
                    kernel_regularizer=l2(k_reg)
                    )
             )
    model.add(GaussianNoise(noise))
    model.add(Dropout(dropout_rate))
    model.add(Dense(512, activation=activation))
    model.add(Dense(512, activation=activation))
    model.add(Dense(out_dim)) #, activation='linear'))

    # configure optimizer & compile model
    opt = Adam(lr=learning_rate, decay=adam_decay)
    model.compile(loss="mse", optimizer=opt)

    #### summarize model
    print("Dropout Rate: " + str(dropout_rate))
    print("Kernal regularizer: " + str(k_reg))
    print("Noise: " + str(noise))
    print("Learning Rate: " + str(learning_rate))
    print("Adam Decay Rate: " + str(adam_decay))
    print(model.summary())
    
    return model

# %%
# Set parameter bounds to be optimized
learning_rate = Real(low=5e-4, high=1e-2, prior="log-uniform", name="learning_rate")
adam_decay = Real(low=0,high=0.1,name="adam_decay")
dropout_rate = Real(low=0, high=0.5, name="dropout_rate")
noise = Real(low=0, high=1e-1, name="noise")
k_reg = Real(low=0, high=0.5, name="k_reg")

dimensions = [learning_rate,
              adam_decay,
              dropout_rate,
              noise,
              k_reg
             ]

default_parameters = [1e-3, 1e-2, 0.15, 2e-2, 0.25]

# %%
@use_named_args(dimensions)
def train_model(k_reg, dropout_rate, learning_rate, noise, adam_decay, verbose=0):

    model = construct_model(k_reg, dropout_rate, learning_rate, noise, adam_decay)
    
    # split training and testing data
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=(1-training_size), random_state=23)
    
    # train model
    prediction = model.fit(x_train, y_train,
                          validation_data=(x_test, y_test),
                          epochs=epochs,
                          batch_size=batch_size,
                          verbose=verbose)
    
    # Finding mean RMSE of testing data
    pred_test = model.predict(x_test)
    RMSE_test = (stats.mean([sqrt(mean_squared_error(y_test[:,0], 
                                                     pred_test[:,0])),
                             sqrt(mean_squared_error(y_test[:,1], 
                                                    pred_test[:,1])),  
                             sqrt(mean_squared_error(y_test[:,2], 
                                                    pred_test[:,2])),
                             sqrt(mean_squared_error(y_test[:,3], 
                                                    pred_test[:,3]))
                            ])
                )
    
    # clear session & reset model graphs
    K.clear_session()
    tf.reset_default_graph()

    return RMSE_test

# %%
# Run Bayesian Optimization and return its results
bayopt_results = gp_minimize(func=train_model, 
                             dimensions=dimensions, 
                             n_random_starts=150,
                             n_calls=340, 
                             n_jobs=-1,
                             kappa=5,
                             x0=default_parameters,
                             random_state=23,
                             verbose=True
                            )
# Out:
# Iteration No: 1 started. Evaluating function at provided point.
# Dropout Rate: 0.15
# Kernal regularizer: 0.25
# Noise: 0.02
# Learning Rate: 0.001
# Adam Decay Rate: 0.01
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 1 ended. Evaluation done at provided point.
# Time taken: 222.8483
# Function value obtained: 0.2919
# Current minimum: 0.2919
# Iteration No: 2 started. Evaluating function at random point.
# Dropout Rate: 0.390839752861842
# Kernal regularizer: 0.22095684217744355
# Noise: 0.05739083828109903
# Learning Rate: 0.0037109528307843016
# Adam Decay Rate: 0.01849884894897025
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 2 ended. Evaluation done at random point.
# Time taken: 197.2581
# Function value obtained: 0.3470
# Current minimum: 0.2919
# Iteration No: 3 started. Evaluating function at random point.
# Dropout Rate: 0.10982631004621216
# Kernal regularizer: 0.21338268370354507
# Noise: 0.08333390981847802
# Learning Rate: 0.0008676672502834004
# Adam Decay Rate: 0.009982011759610825
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 3 ended. Evaluation done at random point.
# Time taken: 198.2669
# Function value obtained: 0.3284
# Current minimum: 0.2919
# Iteration No: 4 started. Evaluating function at random point.
# Dropout Rate: 4.154555652169379e-05
# Kernal regularizer: 0.209560613998871
# Noise: 0.09759548424898229
# Learning Rate: 0.004793932659036752
# Adam Decay Rate: 0.09968655622374085
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 4 ended. Evaluation done at random point.
# Time taken: 202.0492
# Function value obtained: 0.3619
# Current minimum: 0.2919
# Iteration No: 5 started. Evaluating function at random point.
# Dropout Rate: 0.2894294906211811
# Kernal regularizer: 0.23978697069908061
# Noise: 0.03949409819240455
# Learning Rate: 0.003852092128698525
# Adam Decay Rate: 0.07526296158513089
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 5 ended. Evaluation done at random point.
# Time taken: 202.3295
# Function value obtained: 0.3415
# Current minimum: 0.2919
# Iteration No: 6 started. Evaluating function at random point.
# Dropout Rate: 0.37806364149052213
# Kernal regularizer: 0.086092055371034
# Noise: 0.0833681270049261
# Learning Rate: 0.001612854264439985
# Adam Decay Rate: 0.06671619870549271
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 6 ended. Evaluation done at random point.
# Time taken: 186.1623
# Function value obtained: 0.3657
# Current minimum: 0.2919
# Iteration No: 7 started. Evaluating function at random point.
# Dropout Rate: 0.21636480044493483
# Kernal regularizer: 0.2353031070111375
# Noise: 0.08760779531940954
# Learning Rate: 0.0009440347289667215
# Adam Decay Rate: 0.08747145186848154
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 7 ended. Evaluation done at random point.
# Time taken: 193.9419
# Function value obtained: 0.3822
# Current minimum: 0.2919
# Iteration No: 8 started. Evaluating function at random point.
# Dropout Rate: 0.0051718823477036055
# Kernal regularizer: 0.23584043635999447
# Noise: 0.06762433136236393
# Learning Rate: 0.0012371938856342822
# Adam Decay Rate: 0.07673224070610607
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 8 ended. Evaluation done at random point.
# Time taken: 203.6145
# Function value obtained: 0.3557
# Current minimum: 0.2919
# Iteration No: 9 started. Evaluating function at random point.
# Dropout Rate: 0.06584099740539669
# Kernal regularizer: 0.3524298615324714
# Noise: 0.08393966745434353
# Learning Rate: 0.0033422436880936883
# Adam Decay Rate: 0.09204269831209305
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 9 ended. Evaluation done at random point.
# Time taken: 204.5350
# Function value obtained: 0.3714
# Current minimum: 0.2919
# Iteration No: 10 started. Evaluating function at random point.
# Dropout Rate: 0.1464029906604691
# Kernal regularizer: 0.07062750026801053
# Noise: 0.014743639661555933
# Learning Rate: 0.00908294166330185
# Adam Decay Rate: 0.09042249296296051
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 10 ended. Evaluation done at random point.
# Time taken: 194.9865
# Function value obtained: 0.3365
# Current minimum: 0.2919
# Iteration No: 11 started. Evaluating function at random point.
# Dropout Rate: 0.14535595656579428
# Kernal regularizer: 0.014968685439237132
# Noise: 0.04887702834288765
# Learning Rate: 0.008720499578063562
# Adam Decay Rate: 4.235535617597154e-05
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 11 ended. Evaluation done at random point.
# Time taken: 197.2295
# Function value obtained: 0.4895
# Current minimum: 0.2919
# Iteration No: 12 started. Evaluating function at random point.
# Dropout Rate: 0.3523960777659563
# Kernal regularizer: 0.09489100083356902
# Noise: 0.0027199925719449966
# Learning Rate: 0.006947471162231323
# Adam Decay Rate: 0.011064255849049602
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 12 ended. Evaluation done at random point.
# Time taken: 176.9491
# Function value obtained: 0.3209
# Current minimum: 0.2919
# Iteration No: 13 started. Evaluating function at random point.
# Dropout Rate: 0.4854924274515475
# Kernal regularizer: 0.39790667562911597
# Noise: 0.04125502797309408
# Learning Rate: 0.005038838065174854
# Adam Decay Rate: 0.07786513483448015
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 13 ended. Evaluation done at random point.
# Time taken: 180.9956
# Function value obtained: 0.3653
# Current minimum: 0.2919
# Iteration No: 14 started. Evaluating function at random point.
# Dropout Rate: 0.18866622907965463
# Kernal regularizer: 0.2824278397544763
# Noise: 0.08232786254285783
# Learning Rate: 0.0020359961603331977
# Adam Decay Rate: 0.04429655143350939
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 14 ended. Evaluation done at random point.
# Time taken: 184.4148
# Function value obtained: 0.3630
# Current minimum: 0.2919
# Iteration No: 15 started. Evaluating function at random point.
# Dropout Rate: 0.015583787011048848
# Kernal regularizer: 0.2611736625383843
# Noise: 0.09284468609047758
# Learning Rate: 0.0007604783115919163
# Adam Decay Rate: 0.09659095216561495
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 15 ended. Evaluation done at random point.
# Time taken: 189.3364
# Function value obtained: 0.3847
# Current minimum: 0.2919
# Iteration No: 16 started. Evaluating function at random point.
# Dropout Rate: 0.12379627471162444
# Kernal regularizer: 0.3916542292492389
# Noise: 0.09890864946050201
# Learning Rate: 0.0005700257416555304
# Adam Decay Rate: 0.06961719680205673
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 16 ended. Evaluation done at random point.
# Time taken: 196.5078
# Function value obtained: 0.3985
# Current minimum: 0.2919
# Iteration No: 17 started. Evaluating function at random point.
# Dropout Rate: 0.2104706777091268
# Kernal regularizer: 0.24450686871484
# Noise: 0.03872656591644528
# Learning Rate: 0.002215992151827114
# Adam Decay Rate: 0.058799176702847414
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 17 ended. Evaluation done at random point.
# Time taken: 215.9271
# Function value obtained: 0.3325
# Current minimum: 0.2919
# Iteration No: 18 started. Evaluating function at random point.
# Dropout Rate: 0.32300880226017914
# Kernal regularizer: 0.46809926818052017
# Noise: 0.08719620744466582
# Learning Rate: 0.0017124433117930433
# Adam Decay Rate: 0.029208044031803312
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 18 ended. Evaluation done at random point.
# Time taken: 176.0439
# Function value obtained: 0.3530
# Current minimum: 0.2919
# Iteration No: 19 started. Evaluating function at random point.
# Dropout Rate: 0.3908999442729749
# Kernal regularizer: 0.04998324348691614
# Noise: 0.031936008182206196
# Learning Rate: 0.0045384733127000025
# Adam Decay Rate: 0.029202926253234424
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 19 ended. Evaluation done at random point.
# Time taken: 179.7485
# Function value obtained: 0.3055
# Current minimum: 0.2919
# Iteration No: 20 started. Evaluating function at random point.
# Dropout Rate: 0.1528000928554231
# Kernal regularizer: 0.42558700593720494
# Noise: 0.04976931172281443
# Learning Rate: 0.00261039600399011
# Adam Decay Rate: 0.07380082761828542
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 20 ended. Evaluation done at random point.
# Time taken: 184.7497
# Function value obtained: 0.3468
# Current minimum: 0.2919
# Iteration No: 21 started. Evaluating function at random point.
# Dropout Rate: 0.27303043335030175
# Kernal regularizer: 0.48983372242547657
# Noise: 0.06661653550939091
# Learning Rate: 0.004847306940110012
# Adam Decay Rate: 0.03306228326167345
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 21 ended. Evaluation done at random point.
# Time taken: 185.7960
# Function value obtained: 0.3633
# Current minimum: 0.2919
# Iteration No: 22 started. Evaluating function at random point.
# Dropout Rate: 0.06613956129441707
# Kernal regularizer: 0.42292109552358675
# Noise: 0.02670074105637142
# Learning Rate: 0.002027896792071881
# Adam Decay Rate: 0.05753625947250568
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 22 ended. Evaluation done at random point.
# Time taken: 184.0545
# Function value obtained: 0.3325
# Current minimum: 0.2919
# Iteration No: 23 started. Evaluating function at random point.
# Dropout Rate: 0.10278075242549908
# Kernal regularizer: 0.35132743271278294
# Noise: 0.026984997608802658
# Learning Rate: 0.0010380277839348161
# Adam Decay Rate: 0.05010657656751201
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 23 ended. Evaluation done at random point.
# Time taken: 195.9388
# Function value obtained: 0.3426
# Current minimum: 0.2919
# Iteration No: 24 started. Evaluating function at random point.
# Dropout Rate: 0.4381111432549151
# Kernal regularizer: 0.10841880770584852
# Noise: 0.02053215176126004
# Learning Rate: 0.0029989911098617173
# Adam Decay Rate: 0.020623960228901023
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 24 ended. Evaluation done at random point.
# Time taken: 196.3993
# Function value obtained: 0.3284
# Current minimum: 0.2919
# Iteration No: 25 started. Evaluating function at random point.
# Dropout Rate: 0.2479866577623307
# Kernal regularizer: 0.028686823842636773
# Noise: 0.040653281869006457
# Learning Rate: 0.0005383607503583506
# Adam Decay Rate: 0.0028030089252449215
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 25 ended. Evaluation done at random point.
# Time taken: 197.8656
# Function value obtained: 0.3116
# Current minimum: 0.2919
# Iteration No: 26 started. Evaluating function at random point.
# Dropout Rate: 0.022589718537146756
# Kernal regularizer: 0.07060557007023928
# Noise: 0.03635309584573892
# Learning Rate: 0.005959547637604818
# Adam Decay Rate: 0.004223296513581643
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 26 ended. Evaluation done at random point.
# Time taken: 175.1225
# Function value obtained: 0.3674
# Current minimum: 0.2919
# Iteration No: 27 started. Evaluating function at random point.
# Dropout Rate: 0.08171408357240385
# Kernal regularizer: 0.052806330784752845
# Noise: 0.030512737735255275
# Learning Rate: 0.0017260253819459384
# Adam Decay Rate: 0.06939332547689879
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 27 ended. Evaluation done at random point.
# Time taken: 178.6697
# Function value obtained: 0.3247
# Current minimum: 0.2919
# Iteration No: 28 started. Evaluating function at random point.
# Dropout Rate: 0.052053274694842014
# Kernal regularizer: 0.391779374418333
# Noise: 0.01274052493042123
# Learning Rate: 0.00967982526245222
# Adam Decay Rate: 0.014630596584668268
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 28 ended. Evaluation done at random point.
# Time taken: 188.5063
# Function value obtained: 0.3093
# Current minimum: 0.2919
# Iteration No: 29 started. Evaluating function at random point.
# Dropout Rate: 0.15611919671653265
# Kernal regularizer: 0.022890612938803515
# Noise: 0.00019136706098201733
# Learning Rate: 0.0008178679388454967
# Adam Decay Rate: 0.00212941762979525
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 29 ended. Evaluation done at random point.
# Time taken: 190.8795
# Function value obtained: 0.3157
# Current minimum: 0.2919
# Iteration No: 30 started. Evaluating function at random point.
# Dropout Rate: 0.44425765782462373
# Kernal regularizer: 0.39674012101528394
# Noise: 0.007552645031202911
# Learning Rate: 0.00091577083110426
# Adam Decay Rate: 0.054746146416859445
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 30 ended. Evaluation done at random point.
# Time taken: 187.2150
# Function value obtained: 0.3357
# Current minimum: 0.2919
# Iteration No: 31 started. Evaluating function at random point.
# Dropout Rate: 0.3840396372795655
# Kernal regularizer: 0.38508380106851475
# Noise: 0.06144465848886889
# Learning Rate: 0.005561785736661913
# Adam Decay Rate: 0.06263052655820012
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 31 ended. Evaluation done at random point.
# Time taken: 189.7729
# Function value obtained: 0.3638
# Current minimum: 0.2919
# Iteration No: 32 started. Evaluating function at random point.
# Dropout Rate: 0.3351890293034167
# Kernal regularizer: 0.2475380827356794
# Noise: 0.07669223851029743
# Learning Rate: 0.0010103424439944482
# Adam Decay Rate: 0.0699105410235966
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# ...
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 330 ended. Search finished for the next optimal point.
# Time taken: 217.7100
# Function value obtained: 0.3321
# Current minimum: 0.2734
# Iteration No: 331 started. Searching for the next optimal point.
# Dropout Rate: 0.23731097629779063
# Kernal regularizer: 0.49657149065527956
# Noise: 0.0008393043808587854
# Learning Rate: 0.0007414782991823368
# Adam Decay Rate: 0.0133397677900603
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 331 ended. Search finished for the next optimal point.
# Time taken: 214.6756
# Function value obtained: 0.3235
# Current minimum: 0.2734
# Iteration No: 332 started. Searching for the next optimal point.
# Dropout Rate: 0.4975834969462399
# Kernal regularizer: 0.48330221563859466
# Noise: 0.0010192063159411016
# Learning Rate: 0.001649940295779952
# Adam Decay Rate: 0.07558807419817015
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 332 ended. Search finished for the next optimal point.
# Time taken: 216.0656
# Function value obtained: 0.3271
# Current minimum: 0.2734
# Iteration No: 333 started. Searching for the next optimal point.
# Dropout Rate: 0.48187167416133264
# Kernal regularizer: 0.4878004877122439
# Noise: 0.0008716738686940675
# Learning Rate: 0.0005766379152974192
# Adam Decay Rate: 0.04956236986439736
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 333 ended. Search finished for the next optimal point.
# Time taken: 209.8825
# Function value obtained: 0.3716
# Current minimum: 0.2734
# Iteration No: 334 started. Searching for the next optimal point.
# Dropout Rate: 0.4737557535616446
# Kernal regularizer: 0.11405459431486195
# Noise: 0.0024795492148362193
# Learning Rate: 0.0005414354746578133
# Adam Decay Rate: 0.012639232850568952
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 334 ended. Search finished for the next optimal point.
# Time taken: 213.3889
# Function value obtained: 0.3122
# Current minimum: 0.2734
# Iteration No: 335 started. Searching for the next optimal point.
# Dropout Rate: 0.009179102119686812
# Kernal regularizer: 0.12004089149187028
# Noise: 0.09662116600062136
# Learning Rate: 0.0005120645273293615
# Adam Decay Rate: 0.038020319727112964
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 335 ended. Search finished for the next optimal point.
# Time taken: 209.8587
# Function value obtained: 0.3539
# Current minimum: 0.2734
# Iteration No: 336 started. Searching for the next optimal point.
# Dropout Rate: 0.053526551714717444
# Kernal regularizer: 0.1584088266262004
# Noise: 0.0021373746221238447
# Learning Rate: 0.009675652413891843
# Adam Decay Rate: 0.0389777366909352
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 336 ended. Search finished for the next optimal point.
# Time taken: 217.7680
# Function value obtained: 0.3127
# Current minimum: 0.2734
# Iteration No: 337 started. Searching for the next optimal point.
# Dropout Rate: 0.034390354876785885
# Kernal regularizer: 0.1482815663702042
# Noise: 3.868465252743204e-06
# Learning Rate: 0.0005022180667334429
# Adam Decay Rate: 0.05070753085692693
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 337 ended. Search finished for the next optimal point.
# Time taken: 213.4476
# Function value obtained: 0.3274
# Current minimum: 0.2734
# Iteration No: 338 started. Searching for the next optimal point.
# Dropout Rate: 0.0063167702846208
# Kernal regularizer: 0.22246923201437774
# Noise: 0.0006598777395239399
# Learning Rate: 0.008130715088013007
# Adam Decay Rate: 0.06439014596627858
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 338 ended. Search finished for the next optimal point.
# Time taken: 213.4678
# Function value obtained: 0.3264
# Current minimum: 0.2734
# Iteration No: 339 started. Searching for the next optimal point.
# Dropout Rate: 0.009735044238935954
# Kernal regularizer: 0.1612323837435757
# Noise: 0.000713818453316917
# Learning Rate: 0.0005324121747254276
# Adam Decay Rate: 0.09693351200577047
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 339 ended. Search finished for the next optimal point.
# Time taken: 217.1366
# Function value obtained: 0.3675
# Current minimum: 0.2734
# Iteration No: 340 started. Searching for the next optimal point.
# Dropout Rate: 0.018670626123104554
# Kernal regularizer: 0.3066844282587556
# Noise: 0.0011748452326568297
# Learning Rate: 0.009448065179669715
# Adam Decay Rate: 0.02863509261226929
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1024)              331776
# _________________________________________________________________
# gaussian_noise_1 (GaussianNo (None, 1024)              0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 2052
# =================================================================
# Total params: 1,121,284
# Trainable params: 1,121,284
# Non-trainable params: 0
# _________________________________________________________________
# None
# Iteration No: 340 ended. Search finished for the next optimal point.
# Time taken: 220.2834
# Function value obtained: 0.3476
# Current minimum: 0.2734

# %%
column_names = ["learning_rate",
                "adam_decay",
                "dropout_rate",
                "noise",
                "k_reg",
               ]

iterations = pd.DataFrame(data=bayopt_results.x_iters, 
                          index=bayopt_results.func_vals, columns=column_names)
print("Best Parameters: "  + str(bayopt_results.x))
# iterations.to_excel(r'2nd_Large_BayOpt.xlsx')
iterations
# Out:
# Best Parameters: [0.003746732751708163, 0.006709578082719618, 0.005789320226934709, 8.381377063769025e-05, 0.24636233956533735]
#           learning_rate  adam_decay  dropout_rate     noise     k_reg
# 0.291948       0.001000    0.010000      0.150000  0.020000  0.250000
# 0.346963       0.003711    0.018499      0.390840  0.057391  0.220957
# 0.328404       0.000868    0.009982      0.109826  0.083334  0.213383
# 0.361916       0.004794    0.099687      0.000042  0.097595  0.209561
# 0.341530       0.003852    0.075263      0.289429  0.039494  0.239787
# ...                 ...         ...           ...       ...       ...
# 0.312719       0.009676    0.038978      0.053527  0.002137  0.158409
# 0.327433       0.000502    0.050708      0.034390  0.000004  0.148282
# 0.326388       0.008131    0.064390      0.006317  0.000660  0.222469
# 0.367473       0.000532    0.096934      0.009735  0.000714  0.161232
# 0.347557       0.009448    0.028635      0.018671  0.001175  0.306684
#
# [340 rows x 5 columns]
