# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from statistics import mean, stdev
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import StratifiedKFold
from collections import defaultdict

from sklearn.inspection import permutation_importance

# %%
def stratify_df(df, label_type, label_site):
    '''
    This function modifies the dataframe so that during cross validation
    the data can be split into test/train datasets that are equally stratified
    in "type" and "site" as the original dataframe.

    Inputs
        - df: pandas df. A ML training dataset that contains targets and
        features.
        - label_type: int. column index of "Type" column. Default: 1.
        - label_site int. column index of "Site" column. Dafault: 4.

    Outputs
        - b: pandas series. A newly encoded column that uniquely identifies
        the 15 possible combinations (3 sc types x 5 impurity sites) that a
        datapoint in the set could fal into.
    '''
    labels = df[df.columns[[label_type, label_site]]]

    # encode sc type and site columns, then combine them into a new string col
    # i.e. sctype 1 and site 3 becomes new column of 13 (dtype: string)
    enc = OrdinalEncoder(dtype=np.int)
    a = enc.fit_transform(labels)
    a = pd.DataFrame(a, columns=["SC_Type", "Site"])
    a = a.applymap(str)
    a = a[["SC_Type", "Site"]].apply(lambda x: ''.join(x), axis=1)

    # encode the new string col to 0-14 (15 total classes -
    # 3 sctypes x 5 defsites)
    b = np.array(a).reshape(-1, 1)
    b = enc.fit_transform(b)

    return b

# %%
def descriptors_outputs(df, d_start, o):
    '''
    This function splits to dataframe up into separate dataframes of
    descriptors and outputs by column.

    Inputs
        - df: pandas df. A ML training dataset that contains targets and
        features.
        - d_start: int. column index to that the descriptors columns start at.
        In the input df, the descriptors must start at some column at index
        df_start to the last column in the dataframe. Default: 3.
        - o: int. column index of the output. Deafult: 0.
    Outputs
        - X: pandas df. Dataframe with descriptors.
        - y: pandas df. Dataframe with output.
    '''
    X = df[df.columns[d_start:]]
    y = df[df.columns[o]]

    return X, y

# %%
#X, y = descriptors_outputs(lasso_a, 5, 0)
#[X.columns]

# %%
def traintest(X, y, train_idx, test_idx):
    '''
    This function splits the descriptors (X) and output (y) points into train
    and test sets. The size of test set depends on the number of folds of CV.

    Inputs
        - X: pandas df. Dataframe with descriptors.
        - y: pandas df. Dataframe with output.
        - train_idx: np array. Indexes of training points.
        - test_idx: np array. Indexes of testing points.

    Outputs
        - X_train: np array. descriptor values of training data set.
        - X_test: np array. descriptor values of test data set.
        - y_train: np array. output values of training data set.
        - y_test: np array. output values of test data set.
    '''
    # train_idx and test_idx come from skf.split
    X_train, X_test = X.iloc[list(train_idx)], X.iloc[list(test_idx)]
    y_train, y_test = y.iloc[list(train_idx)], y.iloc[list(test_idx)]

    return X_train, X_test, y_train, y_test

# %%
def fit_predict(X_train, y_train, X_test, clf):
    '''
    This function fits the training X/y data using the RFR model. Then makes a
    train and test prediction of the target value for each point, using the
    descriptors of training and testing. For each fold of the cross validation,
    the training and testing sets will change.

    Inputs
        - X_train: np array. descriptor values of training data set.
        - y_train: np array. output values of training data set.
        - X_test: np array. descriptor values of test data set.
        - clf: RandomForestRegressor from sklearn

    Outputs
        - trainpred: np array. predicted output value for every point in the
        train data set.
        - testpred: np array. predicted output value for every point in the
        test data set.
    '''
    # fit all the training data
    clf.fit(X_train, y_train)

    # predict on training data and testing data based on fit model
    trainpred = clf.predict(X_train)
    testpred = clf.predict(X_test)

    return trainpred, testpred,

# %%
def rfr_permute(df, o=0, d_start=5, num_trees=100, max_feat='auto',
                  max_depth=5, min_samp_leaf=2, min_samples_split=5,
                  folds=5, label_type=1, label_site=4):
    '''
    This is a wrapper func that performs RFR with cross validation on a set of
    data with observed values and descriptors. For each  fold of CV, points
    are predicted for the train and test data. The function returns train and
    test dictionaries that contain the fold of CV as the key, and the a
    dataframe of type, ab, impurity, site, dft values, predicted values for
    every point in the train or test set in that fold.

    Inputs
        - df: pandas df. A ML training dataset that contains targets and
        features.
        - o: int. column index of the output. Deafult: 0.
        - d_start: int. column index to that the descriptors columns start at.
        In the input df, the descriptors must start at some column at index
        df_start to the last column in the dataframe. Default: 5.
        - num_trees: int. Number of estimators (trees) to by used by the
        RFR in the random forest. Default:100.
        - max_feat: str. The number of features to consider when looking for
        the best split. Default: 'auto'
        - max_depth: int. The maximum depth of each tree in the forest.
        Keep this value low to mitigate overfitting. Default:5.
        - min_samp_leaf: int. The minimum number of samples required to be at
         a leaf node. Deafult: 2.
        - min_samples_split: int. The minimum number of samples required to
         split an internal node. Default: 5.
        - folds: int. Number of folds to to split the data in cross validation.
        Default: 5.
        - label_type: int. column index of "Type" column in DFT training
        dataframe. Default: 1.
        - label_site int. column index of "Site" column in DFT training
        dataframe. Dafault: 4.

    Outputs
        - folds_dict_train: pandas df. key is CV fold, value is dataframe of
         type, ab, impurity, site, dft values, predicted values for every
         point in the train set in that fold.
        - folds_dict_test: pandas df.  key is CV fold, value is dataframe of
         type, ab, impurity, site, dft values, predicted values for every
         point in the test set in that fold.
    '''
    # make the dataframe stratifiable by type and site
    b = stratify_df(df, label_type, label_site)

    # identify the descriptor columns and output column
    X, y = descriptors_outputs(df, d_start, o)

    # establish the stratified k-fold cross validation, folds in an input
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=130)

    # establish the RFR classifier with certain parameters, which are inputs
    clf = RandomForestRegressor(n_estimators=num_trees, max_features=max_feat,
                                max_depth=max_depth,
                                min_samples_leaf=min_samp_leaf,
                                min_samples_split=min_samples_split,
                                n_jobs=2, random_state=130)

    i=1
    permute_list = []
    for train_idx, test_idx in skf.split(df, b):

        X_train, X_test, y_train, y_test = traintest(X, y, train_idx, test_idx)

        clf.fit(X_train, y_train)

        result = permutation_importance(clf, X_test, y_test, n_repeats=10, random_state=130, n_jobs=-1)
        
        feature_names = X.columns.tolist()
        
        forest_importances = pd.DataFrame(data={'predictor': feature_names, 
                                                'fold {}'.format(i):result.importances_mean})
        
        permute_list.append(forest_importances)
        #print(permute_list)
        
        i+=1
        
    result = pd.concat(permute_list, axis=1)
    result.drop(['predictor'], axis=1, inplace=True)
    result.insert(0, 'predictor', feature_names)
    result.set_index('predictor', inplace=True)
    result['mean'] = result.mean(axis=1)
    result['std dev'] = result.std(axis=1)
    

    return result

# %% [markdown]
# # Feature Importance
# I am ultimately reporting feature importance based on feature permutation: using the sklearn library `inspection.permutation_importance` (sklearn.inspection.permutation_importance —scikit-learn 1.0 documentation) because it could be computed on the left out test set which I found useful. To score importance I used the estimator’s default scorer -but I can change this to rmse, though I think feature importances will be ranked relatively the same.
#
# I also checked feature importance based on mean decrease in impurity (a property of the RFR model) and found feature importances were ranked approximately the same between the two methods.
#
# The feature importance for each output are listed by most to least importance. Importance was calculated on “held out set” over 5 rounds of CV. The mean and std deviation of the five rounds is reported in .csv files (importance ranked by mean).

# %% [markdown]
# # dHA

# %%
lasso_a = pd.read_csv('./xiaofeng_lasso/dataset_7p7/Lasso_HA_7.7.csv')

# %%
lassoa_featimport = rfr_permute(lasso_a, d_start=5, max_depth=10, max_feat='auto', 
                             min_samp_leaf=2, min_samples_split=15,
                             num_trees=600, folds=5)

# %%
lassoa_featimport.sort_values(by=['mean'], ascending=False)
# Out:
#                                                 fold 1    fold 2    fold 3  \
# predictor
# abs(Group.3-Heat_vap.3)                       0.155717  0.173314  0.165763
# MP.2*BP.2                                     0.035523  0.065456  0.019582
# abs(Electronegativity.3-Electronegativity.2)  0.043864  0.028261  0.039317
# abs(Valence.3-Valence.2)                      0.036058  0.032654  0.052738
# PBE_latt_const^3                              0.049815  0.017055  0.049451
# ...                                                ...       ...       ...
# abs(Thermal_expn.2-CM1)                      -0.000409  0.000301  0.000333
# MP^3                                          0.000107 -0.000088 -0.000001
# Elec_cond/Ion_Energy.1                        0.000056  0.000140 -0.000052
# Elec_cond/Ion_pot_1.1                        -0.000032  0.000252 -0.000129
# abs(Sp_heat_cap.3-CM1)                        0.000605  0.000493 -0.000180
#
#                                                 fold 4    fold 5  \
# predictor
# abs(Group.3-Heat_vap.3)                       0.081492  0.187524
# MP.2*BP.2                                     0.026693  0.049339
# abs(Electronegativity.3-Electronegativity.2)  0.039755  0.036549
# abs(Valence.3-Valence.2)                      0.023740  0.020527
# PBE_latt_const^3                              0.012741  0.000839
# ...                                                ...       ...
# abs(Thermal_expn.2-CM1)                       0.000353  0.000503
# MP^3                                         -0.000047  0.000229
# Elec_cond/Ion_Energy.1                       -0.000019  0.000018
# Elec_cond/Ion_pot_1.1                         0.000258 -0.000210
# abs(Sp_heat_cap.3-CM1)                        0.000363 -0.001280
#
#                                                       mean   std dev
# predictor
# abs(Group.3-Heat_vap.3)                       1.527619e-01  0.037116
# MP.2*BP.2                                     3.931885e-02  0.016413
# abs(Electronegativity.3-Electronegativity.2)  3.754900e-02  0.005199
# abs(Valence.3-Valence.2)                      3.314345e-02  0.011316
# PBE_latt_const^3                              2.598029e-02  0.020030
# ...                                                    ...       ...
# abs(Thermal_expn.2-CM1)                       2.163573e-04  0.000321
# MP^3                                          3.996014e-05  0.000115
# Elec_cond/Ion_Energy.1                        2.868566e-05  0.000066
# Elec_cond/Ion_pot_1.1                         2.796656e-05  0.000194
# abs(Sp_heat_cap.3-CM1)                        8.545105e-08  0.000695
#
# [108 rows x 7 columns]

# %%
#lassoa_featimport.to_csv('./feature_importance/lassoa_featureimportance.csv')

# %%
#lassoa_featimport_diff = rfr_descrip(lasso_a, d_start=5, max_depth=10, max_feat='auto', 
                             #min_samp_leaf=2, min_samples_split=15,
                             #num_trees=600, folds=5)

# %% [markdown]
# # dHB

# %%
lasso_b = pd.read_csv('./xiaofeng_lasso/dataset_7p7/Lasso_HB_7.7.csv')

# %%
lassob_featimport = rfr_permute(lasso_b, d_start=5, max_depth=10, max_feat='auto', 
                             min_samp_leaf=3, min_samples_split=15,
                             num_trees=1000, folds=5)

# %%
lassob_featimport.sort_values(by=['mean'], ascending=False)
# Out:
#                                          fold 1    fold 2    fold 3    fold 4  \
# predictor
# abs(Thermal_expn.3-Thermal_expn.2)     0.258081  0.227807  0.234781  0.178244
# Ion_pot_2.2+At_rad_2.1                 0.060041  0.047441  0.091738  0.073460
# BP.2-CM6                               0.023712  0.022488  0.032893  0.048547
# Valence.3-Valence.2                    0.008627  0.012849  0.023510  0.029714
# BP.3-At_rad_2.1                        0.014839  0.034221  0.013459  0.009406
# ...                                         ...       ...       ...       ...
# abs(Electronegativity.3-Ion_Energy.3)  0.000212  0.000919  0.000696 -0.000211
# abs(Elec_cond.2-CM1)                  -0.000052 -0.000050  0.000630  0.000220
# abs(At_rad_2.2-MP)                    -0.000226  0.000197  0.000572  0.000031
# At_rad_2^3                             0.000072 -0.000001  0.000072  0.000053
# MP^3                                   0.000089  0.000009  0.000002  0.000047
#
#                                          fold 5      mean   std dev
# predictor
# abs(Thermal_expn.3-Thermal_expn.2)     0.202504  0.220284  0.027491
# Ion_pot_2.2+At_rad_2.1                 0.081095  0.070755  0.015575
# BP.2-CM6                               0.062407  0.038009  0.015348
# Valence.3-Valence.2                    0.022915  0.019523  0.007675
# BP.3-At_rad_2.1                        0.011751  0.016735  0.008929
# ...                                         ...       ...       ...
# abs(Electronegativity.3-Ion_Energy.3) -0.000828  0.000157  0.000629
# abs(Elec_cond.2-CM1)                  -0.000055  0.000139  0.000267
# abs(At_rad_2.2-MP)                    -0.000126  0.000089  0.000281
# At_rad_2^3                             0.000064  0.000052  0.000027
# MP^3                                   0.000097  0.000049  0.000039
#
# [119 rows x 7 columns]

# %%
#lassob_featimport.to_csv('./feature_importance/lassob_featureimportance.csv')

# %% [markdown]
# # +3/+2

# %%
lasso_p32 = pd.read_csv('./xiaofeng_lasso/dataset_7p7/Lasso_(+3,+2)_7.7.csv')

# %%
lassop32_featimport = rfr_permute(lasso_p32, d_start=5, max_depth=7, max_feat='auto', 
                             min_samp_leaf=3, min_samples_split=3,
                             num_trees=450, folds=5)

# %%
lassop32_featimport.sort_values(by=['mean'], ascending=False)
# Out:
#                              fold 1    fold 2    fold 3    fold 4    fold 5  \
# predictor
# abs(Valence.3-Valence.2)   0.335369  0.254084  0.296486  0.333148  0.164186
# At_rad_1.2+At_rad_1        0.105441  0.071145  0.023896  0.064488  0.077609
# abs(ICSD_vol.3-Ion_rad.3)  0.031544  0.020338  0.048561  0.092805  0.009980
# MP/Group.3                 0.030958  0.031272  0.024700  0.048298  0.016866
# abs(Group.3-Mend_num.2)    0.029880  0.013596  0.004846  0.014678  0.032115
# ...                             ...       ...       ...       ...       ...
# Density.3/Thermal_expn.2  -0.000027  0.000490 -0.001230 -0.000717  0.000142
# abs(At_num.3-At_wt.3)      0.000127 -0.000833 -0.000024  0.000171 -0.001146
# abs(Elec_cond.3-At_vol.3) -0.000685 -0.000302 -0.000153 -0.000091 -0.000921
# Ox_state.3/Density.2      -0.000980 -0.000228 -0.000514  0.001304 -0.002127
# Density.2/Ion_pot_2.3     -0.000123 -0.000177 -0.000904 -0.000049 -0.001645
#
#                                mean   std dev
# predictor
# abs(Valence.3-Valence.2)   0.276655  0.063546
# At_rad_1.2+At_rad_1        0.068516  0.026307
# abs(ICSD_vol.3-Ion_rad.3)  0.040646  0.029048
# MP/Group.3                 0.030419  0.010364
# abs(Group.3-Mend_num.2)    0.019023  0.010379
# ...                             ...       ...
# Density.3/Thermal_expn.2  -0.000269  0.000621
# abs(At_num.3-At_wt.3)     -0.000341  0.000543
# abs(Elec_cond.3-At_vol.3) -0.000430  0.000321
# Ox_state.3/Density.2      -0.000509  0.001114
# Density.2/Ion_pot_2.3     -0.000580  0.000615
#
# [87 rows x 7 columns]

# %%
#lassop32_featimport.to_csv('./feature_importance/lassop32_featureimportance.csv')

# %% [markdown]
# # +2/+1

# %%
lasso_p21 = pd.read_csv('./xiaofeng_lasso/dataset_7p7/Lasso_(+2,+1)_7.7.csv')

# %%
lassop21_featimport = rfr_permute(lasso_p21, d_start=5, max_depth=9, max_feat='auto', 
                             min_samp_leaf=7, min_samples_split=2,
                             num_trees=600, folds=5)

# %%
lassop21_featimport.sort_values(by=['mean'], ascending=False)
# Out:
#                                          fold 1    fold 2    fold 3    fold 4  \
# predictor
# abs(Ox_state.3-Ox_state.2)             0.072242  0.075549  0.057141  0.110778
# abs(Valence.3-Valence.2)               0.096934  0.136553  0.093118  0.049718
# Electronegativity.3-At_rad_1.3         0.081482  0.086853  0.080452  0.074388
# abs(Ion_pot_2.3-Therm_cond.1)          0.051982  0.043507  0.126002  0.052928
# Ion_pot_2.3-ICSD_vol.2                 0.055802  0.038494  0.054196  0.045945
# Electronegativity.3-Sp_heat_cap.1      0.016017  0.021308  0.028657  0.018137
# Elec_Aff.3+At_rad_2.1                  0.013890  0.013987  0.029868  0.006927
# Therm_cond.1/Ion_pot_2.3               0.021379  0.007492  0.007479  0.018771
# abs(Group.3-Mend_num.2)                0.009725  0.021576  0.008694  0.004274
# Thermal_expn.2-At_rad_2.1              0.005687  0.013909  0.010620  0.002626
# PBE_gap                                0.006172  0.009519  0.011849  0.007755
# Electronegativity.3+Electronegativity  0.009152  0.010732  0.000618  0.006288
# abs(Elec_cond.3-Elec_cond.2)           0.005865  0.004492  0.013037  0.002891
# abs(Elec_Aff.1-Ion_rad.1)              0.008765  0.007012  0.006872  0.003832
# Ox_state.3-Electronegativity.3         0.001913  0.005056  0.007698  0.007482
# Sp_heat_cap/Ion_pot_2.2                0.008020  0.003072  0.004756  0.002705
# abs(Elec_Aff.3-Mend_num.1)             0.008982  0.004120  0.004959 -0.001019
# Density.3+Ion_pot_2.2                  0.002841  0.001046  0.006499  0.005631
# Electronegativity.3-Elec_cond          0.001156  0.005581  0.002798  0.003314
# abs(Density.3-Cov_rad)                 0.002529  0.005220  0.003550  0.002266
# abs(Ion_Energy.3-MP)                   0.006754  0.003149  0.002497  0.003040
# abs(At_vol.3-At_vol.2)                 0.001310  0.001583  0.004986  0.002579
# Heat_fusion/Ion_pot_2.3                0.001712  0.000013  0.004330  0.005899
# Ox_state.3/Ion_pot_2.2                 0.002435  0.003227  0.000983  0.001072
# Therm_cond.1/Ion_pot_2.2               0.002980  0.000055  0.004228  0.001939
# abs(Elec_Aff.3-Group.1)                0.003229  0.003602  0.003141 -0.000897
# Ox_state.2+Ox_state.1                  0.002988  0.002231  0.002012  0.001488
# abs(Elec_Aff.2-Elec_Aff.1)             0.002261  0.002660  0.003678 -0.000864
# abs(Therm_cond.3-Ion_Energy.2)         0.001760  0.000448  0.003094  0.001995
# Therm_cond.2+At_rad_2.1                0.000154  0.001778  0.005352  0.000170
# abs(Ion_pot_2.3-Ion_pot_2)             0.002843  0.000179  0.001666  0.000379
# abs(Thermal_expn.1-At_rad_2)           0.002580  0.002837  0.002479 -0.003121
# Thermal_expn.3/At_vol.2                0.001978  0.000637  0.001226  0.001686
# Ox_state.2+Ion_pot_1                   0.001295  0.002409  0.001216  0.000747
# Sp_heat_cap/Elec_Aff.2                 0.001929  0.003393  0.001788  0.001660
# abs(At_vol.3-MP)                       0.002571  0.001409 -0.000500  0.000784
# abs(Elec_cond.3-Ion_pot_2)             0.000808  0.001216  0.000763  0.000855
# CM8+Ox_state.1                         0.001148  0.000815  0.001701 -0.000238
# abs(At_rad_2.3-At_rad_2)               0.001228  0.001109  0.000993  0.001135
# CM2+Therm_cond                         0.001907  0.001602  0.000278  0.000563
# abs(At_num.3-At_wt.2)                  0.000941  0.001741  0.000780 -0.000413
# Thermal_expn.3/ICSD_vol.3              0.001353  0.000929  0.000211  0.001042
# abs(Elec_cond.3-Therm_cond.1)         -0.001563  0.000483  0.001543  0.002462
# abs(Ion_pot_2.2-Ion_pot_1.2)           0.001173 -0.000111  0.001331  0.000874
# Therm_cond.2+Density.1                 0.000030  0.001623  0.000914 -0.000239
# abs(Ion_pot_2-Eps_ion)                 0.001162  0.000552  0.000368  0.000073
# Ion_Energy.2-At_rad_2.1               -0.000839  0.001571  0.001651 -0.000006
# abs(Ion_pot_1.2-Therm_cond.1)         -0.000198  0.000659  0.000842  0.001166
# Group.2*MP.2                           0.001515  0.000549  0.000504 -0.000282
# abs(Sp_heat_cap.3-Elec_cond.2)         0.000999  0.001046  0.000466 -0.002135
# abs(Therm_cond.3-Sp_heat_cap.2)        0.000926  0.002208  0.000313 -0.001649
# Ion_pot_1.2-Density.1                  0.000099  0.000761  0.000486 -0.000016
# Sp_heat_cap.2+MP                       0.000360  0.001495 -0.000291  0.000339
# Ion_pot_1.2-At_rad_2.1                -0.000924  0.000740  0.001723 -0.000338
#
#                                          fold 5      mean   std dev
# predictor
# abs(Ox_state.3-Ox_state.2)             0.135101  0.090162  0.028529
# abs(Valence.3-Valence.2)               0.067147  0.088694  0.029534
# Electronegativity.3-At_rad_1.3         0.049045  0.074444  0.013302
# abs(Ion_pot_2.3-Therm_cond.1)          0.062403  0.067364  0.029924
# Ion_pot_2.3-ICSD_vol.2                 0.086779  0.056243  0.016480
# Electronegativity.3-Sp_heat_cap.1      0.011595  0.019143  0.005709
# Elec_Aff.3+At_rad_2.1                  0.014691  0.015873  0.007547
# Therm_cond.1/Ion_pot_2.3               0.012508  0.013526  0.005713
# abs(Group.3-Mend_num.2)                0.009177  0.010689  0.005777
# Thermal_expn.2-At_rad_2.1              0.012707  0.009110  0.004290
# PBE_gap                                0.008276  0.008714  0.001900
# Electronegativity.3+Electronegativity  0.015726  0.008503  0.004993
# abs(Elec_cond.3-Elec_cond.2)           0.009491  0.007155  0.003661
# abs(Elec_Aff.1-Ion_rad.1)              0.008256  0.006948  0.001716
# Ox_state.3-Electronegativity.3         0.009929  0.006416  0.002729
# Sp_heat_cap/Ion_pot_2.2                0.002848  0.004280  0.002010
# abs(Elec_Aff.3-Mend_num.1)             0.003026  0.004014  0.003222
# Density.3+Ion_pot_2.2                  0.001948  0.003593  0.002115
# Electronegativity.3-Elec_cond          0.003902  0.003350  0.001442
# abs(Density.3-Cov_rad)                 0.003060  0.003325  0.001046
# abs(Ion_Energy.3-MP)                   0.000827  0.003254  0.001938
# abs(At_vol.3-At_vol.2)                 0.004685  0.003029  0.001538
# Heat_fusion/Ion_pot_2.3                0.002542  0.002899  0.002045
# Ox_state.3/Ion_pot_2.2                 0.006345  0.002812  0.001958
# Therm_cond.1/Ion_pot_2.2               0.003565  0.002553  0.001458
# abs(Elec_Aff.3-Group.1)                0.002923  0.002400  0.001663
# Ox_state.2+Ox_state.1                  0.002919  0.002328  0.000566
# abs(Elec_Aff.2-Elec_Aff.1)             0.001629  0.001873  0.001522
# abs(Therm_cond.3-Ion_Energy.2)         0.001426  0.001745  0.000857
# Therm_cond.2+At_rad_2.1                0.000839  0.001659  0.001940
# abs(Ion_pot_2.3-Ion_pot_2)             0.003226  0.001659  0.001240
# abs(Thermal_expn.1-At_rad_2)           0.003366  0.001628  0.002394
# Thermal_expn.3/At_vol.2                0.001871  0.001479  0.000494
# Ox_state.2+Ion_pot_1                   0.001427  0.001419  0.000546
# Sp_heat_cap/Elec_Aff.2                -0.001736  0.001407  0.001691
# abs(At_vol.3-MP)                       0.001815  0.001216  0.001036
# abs(Elec_cond.3-Ion_pot_2)             0.001662  0.001061  0.000341
# CM8+Ox_state.1                         0.001603  0.001006  0.000699
# abs(At_rad_2.3-At_rad_2)               0.000531  0.000999  0.000246
# CM2+Therm_cond                         0.000117  0.000893  0.000724
# abs(At_num.3-At_wt.2)                  0.001414  0.000893  0.000737
# Thermal_expn.3/ICSD_vol.3              0.000885  0.000884  0.000374
# abs(Elec_cond.3-Therm_cond.1)          0.001439  0.000873  0.001370
# abs(Ion_pot_2.2-Ion_pot_1.2)           0.000909  0.000835  0.000503
# Therm_cond.2+Density.1                 0.001058  0.000677  0.000686
# abs(Ion_pot_2-Eps_ion)                 0.001140  0.000659  0.000430
# Ion_Energy.2-At_rad_2.1                0.000869  0.000649  0.000953
# abs(Ion_pot_1.2-Therm_cond.1)          0.000598  0.000613  0.000451
# Group.2*MP.2                           0.000714  0.000600  0.000572
# abs(Sp_heat_cap.3-Elec_cond.2)         0.002504  0.000576  0.001515
# abs(Therm_cond.3-Sp_heat_cap.2)        0.000971  0.000554  0.001262
# Ion_pot_1.2-Density.1                  0.001079  0.000482  0.000407
# Sp_heat_cap.2+MP                      -0.000105  0.000360  0.000621
# Ion_pot_1.2-At_rad_2.1                 0.000277  0.000295  0.000908

# %%
#lassop21_featimport.to_csv('./feature_importance/lassop21_featureimportance.csv')

# %% [markdown]
# # +1/0

# %%
lasso_0p1 = pd.read_csv('./xiaofeng_lasso/dataset_7p7/Lasso_(+1,0)_7.7.csv')

# %%
lassop01_featimport = rfr_permute(lasso_0p1, d_start=5, max_depth=10, max_feat='auto', 
                             min_samp_leaf=8, min_samples_split=12,
                             num_trees=150, folds=5)

# %%
lassop01_featimport.sort_values(by=['mean'], ascending=False)
# Out:
#                                                 fold 1    fold 2    fold 3  \
# predictor
# abs(Electronegativity.3-Electronegativity.2)  0.036910  0.061396  0.068873
# Ion_pot_2.3-Ion_pot_2.1                       0.059486  0.072057  0.020226
# Ion_Energy.3-Ion_pot_2.1                      0.072955  0.046676  0.039647
# Electronegativity.3+At_rad_2.1                0.017568  0.030802  0.049498
# Ion_Energy.3-Ion_Energy.1                     0.009471  0.022609  0.013342
# ...                                                ...       ...       ...
# abs(CM1-At_rad_2.1)                           0.000552  0.000671 -0.000421
# Elec_cond.2-Ox_state.1                        0.000153 -0.000218  0.000018
# abs(Electronegativity.3-BP.1)                 0.000868  0.000280  0.000037
# Ox_state.1*Thermal_expn                       0.000260  0.000205  0.000442
# Therm_cond+Ion_Energy                        -0.000250  0.000115  0.000167
#
#                                                 fold 4    fold 5      mean  \
# predictor
# abs(Electronegativity.3-Electronegativity.2)  0.074501  0.059184  0.060173
# Ion_pot_2.3-Ion_pot_2.1                       0.051408  0.039523  0.048540
# Ion_Energy.3-Ion_pot_2.1                      0.021194  0.045698  0.045234
# Electronegativity.3+At_rad_2.1                0.027543  0.020074  0.029097
# Ion_Energy.3-Ion_Energy.1                     0.049524  0.017417  0.022472
# ...                                                ...       ...       ...
# abs(CM1-At_rad_2.1)                           0.000007  0.001108  0.000383
# Elec_cond.2-Ox_state.1                        0.000106  0.001535  0.000319
# abs(Electronegativity.3-BP.1)                 0.000297  0.000079  0.000312
# Ox_state.1*Thermal_expn                       0.000059  0.000524  0.000298
# Therm_cond+Ion_Energy                         0.000299  0.000426  0.000151
#
#                                                std dev
# predictor
# abs(Electronegativity.3-Electronegativity.2)  0.012842
# Ion_pot_2.3-Ion_pot_2.1                       0.017687
# Ion_Energy.3-Ion_pot_2.1                      0.016613
# Electronegativity.3+At_rad_2.1                0.011277
# Ion_Energy.3-Ion_Energy.1                     0.014211
# ...                                                ...
# abs(CM1-At_rad_2.1)                           0.000534
# Elec_cond.2-Ox_state.1                        0.000621
# abs(Electronegativity.3-BP.1)                 0.000297
# Ox_state.1*Thermal_expn                       0.000167
# Therm_cond+Ion_Energy                         0.000228
#
# [62 rows x 7 columns]

# %%
#lassop01_featimport.to_csv('./feature_importance/lassop01_featureimportance.csv')

# %% [markdown]
# # 0/-1

# %%
lasso_0m1 = pd.read_csv('./xiaofeng_lasso/dataset_7p7/Lasso_(0,-1)_7.7.csv')

# %%
lassom01_featimport = rfr_permute(lasso_0m1, d_start=5, max_depth=8, max_feat='auto', 
                             min_samp_leaf=5, min_samples_split=3,
                             num_trees=150, folds=5)

# %%
lassom01_featimport.sort_values(by=['mean'], ascending=False)
# Out:
#                                                 fold 1    fold 2    fold 3  \
# predictor
# Thermal_expn.2+Therm_cond.1                   0.213922  0.340325  0.288275
# Sp_heat_cap/PBE_delta_H                       0.013314  0.082861  0.028426
# Electronegativity.3+At_rad_2.1                0.008754  0.023794  0.020481
# Thermal_expn.2+At_rad_2.1                     0.015379  0.027101  0.007560
# abs(Electronegativity.3-Electronegativity.2)  0.018433  0.018259  0.008685
# ...                                                ...       ...       ...
# CM6-At_rad_1                                 -0.000412 -0.000276 -0.000153
# CM6-Cov_rad                                  -0.000268 -0.000239  0.000022
# CM6+Sp_heat_cap                              -0.000116 -0.000155 -0.000327
# At_rad_1.3+Ion_Energy.1                      -0.000038  0.000621 -0.001116
# abs(At_rad_2.2-Elec_Aff.1)                   -0.000399  0.000649 -0.001132
#
#                                                 fold 4    fold 5      mean  \
# predictor
# Thermal_expn.2+Therm_cond.1                   0.238698  0.178076  0.251859
# Sp_heat_cap/PBE_delta_H                       0.039695  0.026430  0.038145
# Electronegativity.3+At_rad_2.1                0.017841  0.004848  0.015144
# Thermal_expn.2+At_rad_2.1                     0.010749  0.009653  0.014088
# abs(Electronegativity.3-Electronegativity.2)  0.010689  0.011335  0.013480
# ...                                                ...       ...       ...
# CM6-At_rad_1                                  0.000230  0.000075 -0.000107
# CM6-Cov_rad                                  -0.000097 -0.000074 -0.000131
# CM6+Sp_heat_cap                               0.000095 -0.000808 -0.000262
# At_rad_1.3+Ion_Energy.1                       0.000471 -0.001328 -0.000278
# abs(At_rad_2.2-Elec_Aff.1)                    0.000102 -0.000869 -0.000330
#
#                                                std dev
# predictor
# Thermal_expn.2+Therm_cond.1                   0.056937
# Sp_heat_cap/PBE_delta_H                       0.023875
# Electronegativity.3+At_rad_2.1                0.007175
# Thermal_expn.2+At_rad_2.1                     0.006992
# abs(Electronegativity.3-Electronegativity.2)  0.004068
# ...                                                ...
# CM6-At_rad_1                                  0.000233
# CM6-Cov_rad                                   0.000108
# CM6+Sp_heat_cap                               0.000304
# At_rad_1.3+Ion_Energy.1                       0.000804
# abs(At_rad_2.2-Elec_Aff.1)                    0.000645
#
# [118 rows x 7 columns]

# %%
#lassom01_featimport.to_csv('./feature_importance/lassom01_featureimportance.csv')

# %% [markdown]
# # -1/-2

# %%
lasso_m12 = pd.read_csv('./xiaofeng_lasso/dataset_7p7/Lasso_(-1,-2)_7.7.csv')

# %%
lassom12_featimport = rfr_permute(lasso_m12, d_start=5, max_depth=10, max_feat='auto', 
                             min_samp_leaf=8, min_samples_split=12,
                             num_trees=750, folds=5)

# %%
lassom12_featimport.sort_values(by=['mean'], ascending=False)
# Out:
#                             fold 1    fold 2    fold 3    fold 4    fold 5  \
# predictor
# At_rad_2.1-Elec_cond      0.262056  0.141322  0.055133  0.287830  0.369431
# Cov_rad/At_rad_2.1        0.095711  0.105303  0.116056  0.136120  0.044520
# Valence.1+Ion_pot_2.1     0.011750  0.065056  0.037650  0.017036  0.011594
# Ion_Energy.1+Ion_pot_1    0.012992  0.030484  0.018872  0.011614  0.025940
# Ion_pot_1.1+Ion_pot_1     0.007232  0.029443  0.021588  0.009384  0.022008
# ...                            ...       ...       ...       ...       ...
# Period.2-Ion_Energy.2     0.000040 -0.000027  0.000054 -0.000312  0.000257
# At_rad_1.3+CM4            0.000107  0.000320 -0.000467  0.000042 -0.000003
# Heat_vap.1*Elec_cond     -0.000047  0.000229 -0.000145  0.000230 -0.000302
# Sp_heat_cap.3+Mend_num.2 -0.000772  0.000786  0.000868  0.000326 -0.001472
# Heat_vap.1/Cov_rad.3     -0.000084  0.001023  0.000468  0.000191 -0.002934
#
#                                   mean   std dev
# predictor
# At_rad_2.1-Elec_cond      2.231543e-01  0.111374
# Cov_rad/At_rad_2.1        9.954165e-02  0.030614
# Valence.1+Ion_pot_2.1     2.861711e-02  0.020580
# Ion_Energy.1+Ion_pot_1    1.998039e-02  0.007292
# Ion_pot_1.1+Ion_pot_1     1.793089e-02  0.008367
# ...                                ...       ...
# Period.2-Ion_Energy.2     2.165596e-06  0.000184
# At_rad_1.3+CM4            4.652299e-08  0.000258
# Heat_vap.1*Elec_cond     -7.254098e-06  0.000210
# Sp_heat_cap.3+Mend_num.2 -5.266295e-05  0.000920
# Heat_vap.1/Cov_rad.3     -2.674411e-04  0.001383
#
# [111 rows x 7 columns]

# %%
#lassom12_featimport.to_csv('./feature_importance/lassom12_featureimportance.csv')

# %% [markdown]
# # -2/-3

# %%
lasso_m23 = pd.read_csv('./xiaofeng_lasso/dataset_7p7/Lasso_(-2,-3)_7.7.csv')

# %%
lassom23_featimport = rfr_permute(lasso_m23, d_start=5, max_depth=10, max_feat='sqrt', 
                             min_samp_leaf=2, min_samples_split=14,
                             num_trees=450, folds=5)

# %%
lassom23_featimport.sort_values(by=['mean'], ascending=False)
# Out:
#                           fold 1    fold 2    fold 3    fold 4    fold 5  \
# predictor
# Cov_rad.1+Mend_num      0.024988  0.024988  0.021421  0.031488  0.013080
# ICSD_vol.1+Mend_num     0.015782  0.014356  0.009448  0.018849  0.005800
# Valence.1+Ion_pot_2.1   0.009520  0.011917  0.008750  0.015914  0.006493
# Ox_state.1+Ion_pot_1.1  0.009551  0.010923  0.008578  0.013564  0.005743
# Ox_state.1+Ion_pot_2.1  0.009646  0.010780  0.007118  0.015041  0.002675
# ...                          ...       ...       ...       ...       ...
# Ox_state.1+Eps_elec     0.000155 -0.000183  0.000273  0.000502 -0.000454
# Eps_ion/Cov_rad         0.000130  0.000235  0.000102  0.000062 -0.000342
# Ion_rad.2+Ion_pot_2     0.000055  0.000312  0.000125 -0.000156 -0.000242
# Eps_ion/At_num          0.000101  0.000239 -0.000157  0.000152 -0.000450
# CM2+Ion_pot_2          -0.000057  0.000153  0.000087  0.000324 -0.000738
#
#                             mean   std dev
# predictor
# Cov_rad.1+Mend_num      0.023193  0.006011
# ICSD_vol.1+Mend_num     0.012847  0.004650
# Valence.1+Ion_pot_2.1   0.010519  0.003206
# Ox_state.1+Ion_pot_1.1  0.009672  0.002583
# Ox_state.1+Ion_pot_2.1  0.009052  0.004089
# ...                          ...       ...
# Ox_state.1+Eps_elec     0.000058  0.000338
# Eps_ion/Cov_rad         0.000038  0.000198
# Ion_rad.2+Ion_pot_2     0.000019  0.000199
# Eps_ion/At_num         -0.000023  0.000251
# CM2+Ion_pot_2          -0.000046  0.000367
#
# [77 rows x 7 columns]

# %%
#lassom23_featimport.to_csv('./feature_importance/lassom23_featureimportance.csv')

# %% [markdown]
# ### Unused funcs

# %%
def rfr_descrip(df, o=0, d_start=5, num_trees=100, max_feat='auto',
                  max_depth=5, min_samp_leaf=2, min_samples_split=5,
                  folds=5, label_type=1, label_site=4):
    
    # make the dataframe stratifiable by type and site
    b = stratify_df(df, label_type, label_site)

    # identify the descriptor columns and output column
    X, y = descriptors_outputs(df, d_start, o)

    # establish the stratified k-fold cross validation, folds in an input
    skf = StratifiedKFold(n_splits=folds, shuffle=True, random_state=130)

    # establish the RFR classifier with certain parameters, which are inputs
    clf = RandomForestRegressor(n_estimators=num_trees, max_features=max_feat,
                                max_depth=max_depth,
                                min_samples_leaf=min_samp_leaf,
                                min_samples_split=min_samples_split,
                                n_jobs=2, random_state=130)

    i=1
    permute_list = []
    for train_idx, test_idx in skf.split(df, b):

        X_train, X_test, y_train, y_test = traintest(X, y, train_idx, test_idx)

        clf.fit(X_train, y_train)

        result = permutation_importance(clf, X_test, y_test, n_repeats=10, random_state=130, n_jobs=-1)
        
        feature_names = X.columns.tolist()
        
        descrip_importance = list(zip(feature_names, clf.feature_importances_))
        #print(descrip_importance2)
        descrip_importance.sort(key=lambda x:x[1])
        descr_df = pd.DataFrame(descrip_importance, columns =['predictor', i])
        print(descr_df)
        
        i+=1
        
    #result = pd.concat(permute_list, axis=1)
    #result.drop(['predictor'], axis=1, inplace=True)
    #result.insert(0, 'predictor', feature_names)
    #result.set_index('predictor', inplace=True)
    #result['mean'] = result.mean(axis=1)
    #result['std dev'] = result.std(axis=1)
    

    #return result
